# %% [markdown]
# ### Score: `[42.5]`
#
# Q1. `[16.5]`
#
# Q2. `[22]`
#
# Q3. `[4]` observation 范围，表示方式

# %%
import pandas as pd
N2= pd.read_csv('co2_annmean_mlo.csv',sep=',', skiprows=43)
print(N2.head(50))
N2_data= N2[['year', 'mean']]
N1 = pd.read_csv('co2_annmean_gl.csv',sep=',', skiprows=37)
print(N1.head(60))
N1_data =N1[['year', 'mean']]
#在尝试后面操作发现读取index出现问题我们跳过前面33行无效信息
gamma = pd.read_csv('global.1751_2014.ems', sep='\s+', skiprows=33)
print(gamma.head(30))
gamma_data = gamma[['Year', 'Total']]
# Out:
#     year    mean   unc
# 0   1959  315.98  0.12
# 1   1960  316.91  0.12
# 2   1961  317.64  0.12
# 3   1962  318.45  0.12
# 4   1963  318.99  0.12
# 5   1964  319.62  0.12
# 6   1965  320.04  0.12
# 7   1966  321.37  0.12
# 8   1967  322.18  0.12
# 9   1968  323.05  0.12
# 10  1969  324.62  0.12
# 11  1970  325.68  0.12
# 12  1971  326.32  0.12
# 13  1972  327.46  0.12
# 14  1973  329.68  0.12
# 15  1974  330.19  0.12
# 16  1975  331.13  0.12
# 17  1976  332.03  0.12
# 18  1977  333.84  0.12
# 19  1978  335.41  0.12
# 20  1979  336.84  0.12
# 21  1980  338.76  0.12
# 22  1981  340.12  0.12
# 23  1982  341.48  0.12
# 24  1983  343.15  0.12
# 25  1984  344.87  0.12
# 26  1985  346.35  0.12
# 27  1986  347.61  0.12
# 28  1987  349.31  0.12
# 29  1988  351.69  0.12
# 30  1989  353.20  0.12
# 31  1990  354.45  0.12
# 32  1991  355.70  0.12
# 33  1992  356.54  0.12
# 34  1993  357.21  0.12
# 35  1994  358.96  0.12
# 36  1995  360.97  0.12
# 37  1996  362.74  0.12
# 38  1997  363.88  0.12
# 39  1998  366.84  0.12
# 40  1999  368.54  0.12
# 41  2000  369.71  0.12
# 42  2001  371.32  0.12
# 43  2002  373.45  0.12
# 44  2003  375.98  0.12
# 45  2004  377.70  0.12
# 46  2005  379.98  0.12
# 47  2006  382.09  0.12
# 48  2007  384.02  0.12
# 49  2008  385.83  0.12
#     year    mean   unc
# 0   1979  336.85  0.11
# 1   1980  338.91  0.07
# 2   1981  340.11  0.09
# 3   1982  340.86  0.03
# 4   1983  342.53  0.05
# 5   1984  344.07  0.07
# 6   1985  345.54  0.07
# 7   1986  346.97  0.08
# 8   1987  348.68  0.10
# 9   1988  351.16  0.07
# 10  1989  352.79  0.07
# 11  1990  354.06  0.06
# 12  1991  355.39  0.06
# 13  1992  356.09  0.07
# 14  1993  356.83  0.07
# 15  1994  358.33  0.08
# 16  1995  360.17  0.05
# 17  1996  361.93  0.04
# 18  1997  363.05  0.04
# 19  1998  365.70  0.05
# 20  1999  367.79  0.06
# 21  2000  368.96  0.06
# 22  2001  370.57  0.04
# 23  2002  372.58  0.04
# 24  2003  375.14  0.04
# 25  2004  376.95  0.05
# 26  2005  378.98  0.05
# 27  2006  381.15  0.05
# 28  2007  382.90  0.05
# 29  2008  385.02  0.04
# 30  2009  386.50  0.04
# 31  2010  388.75  0.06
# 32  2011  390.62  0.05
# 33  2012  392.65  0.07
# 34  2013  395.40  0.06
# 35  2014  397.34  0.05
# 36  2015  399.65  0.05
# 37  2016  403.06  0.07
# 38  2017  405.22  0.08
# 39  2018  407.61  0.07
# 40  2019  410.07  0.08
# 41  2020  412.44  0.07
# 42  2021  414.70  0.07
# 43  2022  417.08  0.08
# 44  2023  419.32  0.10
#     Year  Total  Gas  Liquids  Solids  Production  Flaring  Capita
# 0   1751      3    0        0       3           0        0     NaN
# 1   1752      3    0        0       3           0        0     NaN
# 2   1753      3    0        0       3           0        0     NaN
# 3   1754      3    0        0       3           0        0     NaN
# 4   1755      3    0        0       3           0        0     NaN
# 5   1756      3    0        0       3           0        0     NaN
# 6   1757      3    0        0       3           0        0     NaN
# 7   1758      3    0        0       3           0        0     NaN
# 8   1759      3    0        0       3           0        0     NaN
# 9   1760      3    0        0       3           0        0     NaN
# 10  1761      3    0        0       3           0        0     NaN
# 11  1762      3    0        0       3           0        0     NaN
# 12  1763      3    0        0       3           0        0     NaN
# 13  1764      3    0        0       3           0        0     NaN
# 14  1765      3    0        0       3           0        0     NaN
# 15  1766      3    0        0       3           0        0     NaN
# 16  1767      3    0        0       3           0        0     NaN
# 17  1768      3    0        0       3           0        0     NaN
# 18  1769      3    0        0       3           0        0     NaN
# 19  1770      3    0        0       3           0        0     NaN
# 20  1771      4    0        0       4           0        0     NaN
# 21  1772      4    0        0       4           0        0     NaN
# 22  1773      4    0        0       4           0        0     NaN
# 23  1774      4    0        0       4           0        0     NaN
# 24  1775      4    0        0       4           0        0     NaN
# 25  1776      4    0        0       4           0        0     NaN
# 26  1777      4    0        0       4           0        0     NaN
# 27  1778      4    0        0       4           0        0     NaN
# 28  1779      4    0        0       4           0        0     NaN
# 29  1780      4    0        0       4           0        0     NaN
# <>:9: SyntaxWarning: invalid escape sequence '\s'
# <>:9: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\胡天龙\AppData\Local\Temp\ipykernel_26848\1218715712.py:9: SyntaxWarning: invalid escape sequence '\s'
#   gamma = pd.read_csv('global.1751_2014.ems', sep='\s+', skiprows=33)

# %%
import pandas as pd
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt

# 设置年份为索引
N1_data.set_index('year', inplace=True)
N2_data.set_index('year', inplace=True)
gamma_data.set_index('Year', inplace=True)

# 获取初始条件
N1_0 = 740
N2_0 = 900

# 定义微分方程模型
def model(Y, t, k12, k21, gamma_func):
    N1, N2 = Y
    gamma_t = gamma_func(t)
    dN1dt = -k12 * N1 + k21 * N2 + gamma_t
    dN2dt = k12 * N1 - k21 * N2
    return [dN1dt, dN2dt]

# 参数
k12 = 105 / 740
k21 = 102 / 900

# 时间序列
t = np.linspace(1987, 2004, 18)

# 定义一个函数来获取gamma值
def gamma_func(t):
    idx = np.argmin(np.abs(gamma_data.index - t))
    return gamma_data.iloc[idx]['Total'] / 1000

# 求解微分方程
solution = odeint(model, [N1_0, N2_0], t, args=(k12, k21, gamma_func))

# 输出求解过程中的数值
for i, (time, state) in enumerate(zip(t, solution)):
    gamma_t = gamma_func(time)
    print(f"Time: {time}, N1: {state[0]}, N2: {state[1]}, gamma: {gamma_t}, k12: {k12}, k21: {k21}")

# 提取结果
N1, N2 = solution.T

# 绘制结果
plt.figure(figsize=(10, 6))
plt.plot(t, N1/2.13, label='Simulated Atmospheric CO2')
plt.xlabel('Year')
plt.ylabel('Concentration (ppm)')
plt.title('CO2 Concentration Simulation')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Time: 1987.0, N1: 740.0, N2: 900.0, gamma: 5.725, k12: 0.14189189189189189, k21: 0.11333333333333333
# Time: 1988.0, N1: 742.8054826015713, N2: 903.0250587856822, gamma: 5.936, k12: 0.14189189189189189, k21: 0.11333333333333333
# Time: 1989.0, N1: 745.7202896884013, N2: 906.1112551116641, gamma: 6.066, k12: 0.14189189189189189, k21: 0.11333333333333333
# Time: 1990.0, N1: 748.6413695255804, N2: 909.2601949881041, gamma: 6.074, k12: 0.14189189189189189, k21: 0.11333333333333333
# Time: 1991.0, N1: 751.5480502218186, N2: 912.4615164682435, gamma: 6.142, k12: 0.14189189189189189, k21: 0.11333333333333333
# Time: 1992.0, N1: 754.4106884043767, N2: 915.7088283149432, gamma: 6.078, k12: 0.14189189189189189, k21: 0.11333333333333333
# Time: 1993.0, N1: 757.2069302433274, N2: 918.9865764665817, gamma: 6.07, k12: 0.14189189189189189, k21: 0.11333333333333333
# Time: 1994.0, N1: 760.0274856101878, N2: 922.2880243647787, gamma: 6.174, k12: 0.14189189189189189, k21: 0.11333333333333333
# Time: 1995.0, N1: 762.9352841778033, N2: 925.6197118242342, gamma: 6.305, k12: 0.14189189189189189, k21: 0.11333333333333333
# Time: 1996.0, N1: 765.9404915117678, N2: 928.9910499196114, gamma: 6.448, k12: 0.14189189189189189, k21: 0.11333333333333333
# Time: 1997.0, N1: 769.0232455862796, N2: 932.4102507400975, gamma: 6.556, k12: 0.14189189189189189, k21: 0.11333333333333333
# Time: 1998.0, N1: 772.120453868951, N2: 935.8790563683378, gamma: 6.576, k12: 0.14189189189189189, k21: 0.11333333333333333
# Time: 1999.0, N1: 775.1785111610116, N2: 939.3894638874765, gamma: 6.561, k12: 0.14189189189189189, k21: 0.11333333333333333
# Time: 2000.0, N1: 778.2810768708121, N2: 942.9339036274429, gamma: 6.733, k12: 0.14189189189189189, k21: 0.11333333333333333
# Time: 2001.0, N1: 781.5045972422793, N2: 946.5233818087322, gamma: 6.893, k12: 0.14189189189189189, k21: 0.11333333333333333
# Time: 2002.0, N1: 784.8045745612247, N2: 950.1669355364097, gamma: 6.994, k12: 0.14189189189189189, k21: 0.11333333333333333
# Time: 2003.0, N1: 788.2858668248413, N2: 953.8706779218961, gamma: 7.376, k12: 0.14189189189189189, k21: 0.11333333333333333
# Time: 2004.0, N1: 792.0514683124152, N2: 957.6645893984864, gamma: 7.743, k12: 0.14189189189189189, k21: 0.11333333333333333

# %%
import pandas as pd
N2= pd.read_csv('co2_annmean_mlo.csv',sep=',', skiprows=43)
print(N2.head(50))
N2_data= N2[['year', 'mean']]
N1 = pd.read_csv('co2_annmean_gl.csv',sep=',', skiprows=37)
print(N1.head(60))
N1_data =N1[['year', 'mean']]
#在尝试后面操作发现读取index出现问题我们跳过前面33行无效信息
gamma = pd.read_csv('global.1751_2014.ems', sep='\s+', skiprows=33)
print(gamma.head(30))
gamma_data = gamma[['Year', 'Total']]
# Out:
#     year    mean   unc
# 0   1959  315.98  0.12
# 1   1960  316.91  0.12
# 2   1961  317.64  0.12
# 3   1962  318.45  0.12
# 4   1963  318.99  0.12
# 5   1964  319.62  0.12
# 6   1965  320.04  0.12
# 7   1966  321.37  0.12
# 8   1967  322.18  0.12
# 9   1968  323.05  0.12
# 10  1969  324.62  0.12
# 11  1970  325.68  0.12
# 12  1971  326.32  0.12
# 13  1972  327.46  0.12
# 14  1973  329.68  0.12
# 15  1974  330.19  0.12
# 16  1975  331.13  0.12
# 17  1976  332.03  0.12
# 18  1977  333.84  0.12
# 19  1978  335.41  0.12
# 20  1979  336.84  0.12
# 21  1980  338.76  0.12
# 22  1981  340.12  0.12
# 23  1982  341.48  0.12
# 24  1983  343.15  0.12
# 25  1984  344.87  0.12
# 26  1985  346.35  0.12
# 27  1986  347.61  0.12
# 28  1987  349.31  0.12
# 29  1988  351.69  0.12
# 30  1989  353.20  0.12
# 31  1990  354.45  0.12
# 32  1991  355.70  0.12
# 33  1992  356.54  0.12
# 34  1993  357.21  0.12
# 35  1994  358.96  0.12
# 36  1995  360.97  0.12
# 37  1996  362.74  0.12
# 38  1997  363.88  0.12
# 39  1998  366.84  0.12
# 40  1999  368.54  0.12
# 41  2000  369.71  0.12
# 42  2001  371.32  0.12
# 43  2002  373.45  0.12
# 44  2003  375.98  0.12
# 45  2004  377.70  0.12
# 46  2005  379.98  0.12
# 47  2006  382.09  0.12
# 48  2007  384.02  0.12
# 49  2008  385.83  0.12
#     year    mean   unc
# 0   1979  336.85  0.11
# 1   1980  338.91  0.07
# 2   1981  340.11  0.09
# 3   1982  340.86  0.03
# 4   1983  342.53  0.05
# 5   1984  344.07  0.07
# 6   1985  345.54  0.07
# 7   1986  346.97  0.08
# 8   1987  348.68  0.10
# 9   1988  351.16  0.07
# 10  1989  352.79  0.07
# 11  1990  354.06  0.06
# 12  1991  355.39  0.06
# 13  1992  356.09  0.07
# 14  1993  356.83  0.07
# 15  1994  358.33  0.08
# 16  1995  360.17  0.05
# 17  1996  361.93  0.04
# 18  1997  363.05  0.04
# 19  1998  365.70  0.05
# 20  1999  367.79  0.06
# 21  2000  368.96  0.06
# 22  2001  370.57  0.04
# 23  2002  372.58  0.04
# 24  2003  375.14  0.04
# 25  2004  376.95  0.05
# 26  2005  378.98  0.05
# 27  2006  381.15  0.05
# 28  2007  382.90  0.05
# 29  2008  385.02  0.04
# 30  2009  386.50  0.04
# 31  2010  388.75  0.06
# 32  2011  390.62  0.05
# 33  2012  392.65  0.07
# 34  2013  395.40  0.06
# 35  2014  397.34  0.05
# 36  2015  399.65  0.05
# 37  2016  403.06  0.07
# 38  2017  405.22  0.08
# 39  2018  407.61  0.07
# 40  2019  410.07  0.08
# 41  2020  412.44  0.07
# 42  2021  414.70  0.07
# 43  2022  417.08  0.08
# 44  2023  419.32  0.10
#     Year  Total  Gas  Liquids  Solids  Production  Flaring  Capita
# 0   1751      3    0        0       3           0        0     NaN
# 1   1752      3    0        0       3           0        0     NaN
# 2   1753      3    0        0       3           0        0     NaN
# 3   1754      3    0        0       3           0        0     NaN
# 4   1755      3    0        0       3           0        0     NaN
# 5   1756      3    0        0       3           0        0     NaN
# 6   1757      3    0        0       3           0        0     NaN
# 7   1758      3    0        0       3           0        0     NaN
# 8   1759      3    0        0       3           0        0     NaN
# 9   1760      3    0        0       3           0        0     NaN
# 10  1761      3    0        0       3           0        0     NaN
# 11  1762      3    0        0       3           0        0     NaN
# 12  1763      3    0        0       3           0        0     NaN
# 13  1764      3    0        0       3           0        0     NaN
# 14  1765      3    0        0       3           0        0     NaN
# 15  1766      3    0        0       3           0        0     NaN
# 16  1767      3    0        0       3           0        0     NaN
# 17  1768      3    0        0       3           0        0     NaN
# 18  1769      3    0        0       3           0        0     NaN
# 19  1770      3    0        0       3           0        0     NaN
# 20  1771      4    0        0       4           0        0     NaN
# 21  1772      4    0        0       4           0        0     NaN
# 22  1773      4    0        0       4           0        0     NaN
# 23  1774      4    0        0       4           0        0     NaN
# 24  1775      4    0        0       4           0        0     NaN
# 25  1776      4    0        0       4           0        0     NaN
# 26  1777      4    0        0       4           0        0     NaN
# 27  1778      4    0        0       4           0        0     NaN
# 28  1779      4    0        0       4           0        0     NaN
# 29  1780      4    0        0       4           0        0     NaN
# <>:9: SyntaxWarning: invalid escape sequence '\s'
# <>:9: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\胡天龙\AppData\Local\Temp\ipykernel_26848\1218715712.py:9: SyntaxWarning: invalid escape sequence '\s'
#   gamma = pd.read_csv('global.1751_2014.ems', sep='\s+', skiprows=33)

# %%
# 设置年份为索引
N1_data.set_index('year', inplace=True)
N2_data.set_index('year', inplace=True)
gamma_data.set_index('Year', inplace=True)

# 获取初始条件
N1_0 = 740
N2_0 = 900
def buffer_factor(z):
    return 3.69 + 1.86e-2 * z - 1.80e-6 * z**2


def gamma_func(t):
    idx = np.argmin(np.abs(gamma_data.index - t))
    return gamma_data.iloc[idx]['Total'] / 1000
    
# 微分方程模型
def model(Y, t, k12, k21, N2_0):
    N1, N2 = Y
    xi = buffer_factor(N1)  # 计算缓冲因子
    gamma_t = gamma_func(t)  # 获取当前时间点的gamma值
    dN1dt = -k12 * N1 + k21 * (N2_00 + xi * (N2 - N2_00)) + gamma_t
    dN2dt = k12 * N1 - k21 * (N2_00 + xi * (N2 - N2_00))
    return [dN1dt, dN2dt]

# 参数
k12 = 105 / 740
k21 = 102 / 900
N2_00 = 821
# 时间序列
t = np.linspace(1987, 2004, 18)

# 求解微分方程
solution = odeint(model, [N1_0, N2_0], t, args=(k12, k21, N2_00))
for i, (time, state) in enumerate(zip(t, solution)):
    gamma_t = gamma_func(time)
    print(f"Time: {time}, N1: {state[0]}, N2: {state[1]}, gamma: {gamma_t}, k12: {k12}, k21: {k21}")

# 提取结果
N1_sim, N2_sim = solution.T

# 绘制结果
plt.figure(figsize=(10, 6))
plt.plot(t, N1_sim/2.13, label='Simulated Atmospheric CO2')
# Out:
# Time: 1987.0, N1: 740.0, N2: 900.0, gamma: 5.725, k12: 0.14189189189189189, k21: 0.11333333333333333
# Time: 1988.0, N1: 805.1131787995563, N2: 840.7173215265278, gamma: 5.936, k12: 0.14189189189189189, k21: 0.11333333333333333
# Time: 1989.0, N1: 818.3989231141161, N2: 833.4325480313009, gamma: 6.066, k12: 0.14189189189189189, k21: 0.11333333333333333
# Time: 1990.0, N1: 825.0417861611991, N2: 832.8596334012207, gamma: 6.074, k12: 0.14189189189189189, k21: 0.11333333333333333
# Time: 1991.0, N1: 830.9144033359579, N2: 833.0950221647521, gamma: 6.142, k12: 0.14189189189189189, k21: 0.11333333333333333
# Time: 1992.0, N1: 836.6941377256109, N2: 833.4252880174424, gamma: 6.078, k12: 0.14189189189189189, k21: 0.11333333333333333
# Time: 1993.0, N1: 842.4317207898022, N2: 833.7616981556683, gamma: 6.07, k12: 0.14189189189189189, k21: 0.11333333333333333
# Time: 1994.0, N1: 848.218650803147, N2: 834.0967723832681, gamma: 6.174, k12: 0.14189189189189189, k21: 0.11333333333333333
# Time: 1995.0, N1: 854.1209171632095, N2: 834.4340124605046, gamma: 6.305, k12: 0.14189189189189189, k21: 0.11333333333333333
# Time: 1996.0, N1: 860.1563599644139, N2: 834.7750727143272, gamma: 6.448, k12: 0.14189189189189189, k21: 0.11333333333333333
# Time: 1997.0, N1: 866.3133206391288, N2: 835.1201172488973, gamma: 6.556, k12: 0.14189189189189189, k21: 0.11333333333333333
# Time: 1998.0, N1: 872.5324789373767, N2: 835.4669531597184, gamma: 6.576, k12: 0.14189189189189189, k21: 0.11333333333333333
# Time: 1999.0, N1: 878.7561051937622, N2: 835.8118241217883, gamma: 6.561, k12: 0.14189189189189189, k21: 0.11333333333333333
# Time: 2000.0, N1: 885.0600441659833, N2: 836.1548846562566, gamma: 6.733, k12: 0.14189189189189189, k21: 0.11333333333333333
# Time: 2001.0, N1: 891.5257474614592, N2: 836.5021812242558, gamma: 6.893, k12: 0.14189189189189189, k21: 0.11333333333333333
# Time: 2002.0, N1: 898.1177847766446, N2: 836.853644897043, gamma: 6.994, k12: 0.14189189189189189, k21: 0.11333333333333333
# Time: 2003.0, N1: 904.9464427609904, N2: 837.2099939871272, gamma: 7.376, k12: 0.14189189189189189, k21: 0.11333333333333333
# Time: 2004.0, N1: 912.1359370654031, N2: 837.579973741196, gamma: 7.743, k12: 0.14189189189189189, k21: 0.11333333333333333

# %%
import pandas as pd
N2= pd.read_csv('co2_annmean_mlo.csv',sep=',', skiprows=43)
print(N2.head(50))
N2_data= N2[['year', 'mean']]
N1 = pd.read_csv('co2_annmean_gl.csv',sep=',', skiprows=37)
print(N1.head(60))
N1_data =N1[['year', 'mean']]
#在尝试后面操作发现读取index出现问题我们跳过前面33行无效信息
gamma = pd.read_csv('global.1751_2014.ems', sep='\s+', skiprows=33)
print(gamma.head(30))
gamma_data = gamma[['Year', 'Total']]
# Out:
#     year    mean   unc
# 0   1959  315.98  0.12
# 1   1960  316.91  0.12
# 2   1961  317.64  0.12
# 3   1962  318.45  0.12
# 4   1963  318.99  0.12
# 5   1964  319.62  0.12
# 6   1965  320.04  0.12
# 7   1966  321.37  0.12
# 8   1967  322.18  0.12
# 9   1968  323.05  0.12
# 10  1969  324.62  0.12
# 11  1970  325.68  0.12
# 12  1971  326.32  0.12
# 13  1972  327.46  0.12
# 14  1973  329.68  0.12
# 15  1974  330.19  0.12
# 16  1975  331.13  0.12
# 17  1976  332.03  0.12
# 18  1977  333.84  0.12
# 19  1978  335.41  0.12
# 20  1979  336.84  0.12
# 21  1980  338.76  0.12
# 22  1981  340.12  0.12
# 23  1982  341.48  0.12
# 24  1983  343.15  0.12
# 25  1984  344.87  0.12
# 26  1985  346.35  0.12
# 27  1986  347.61  0.12
# 28  1987  349.31  0.12
# 29  1988  351.69  0.12
# 30  1989  353.20  0.12
# 31  1990  354.45  0.12
# 32  1991  355.70  0.12
# 33  1992  356.54  0.12
# 34  1993  357.21  0.12
# 35  1994  358.96  0.12
# 36  1995  360.97  0.12
# 37  1996  362.74  0.12
# 38  1997  363.88  0.12
# 39  1998  366.84  0.12
# 40  1999  368.54  0.12
# 41  2000  369.71  0.12
# 42  2001  371.32  0.12
# 43  2002  373.45  0.12
# 44  2003  375.98  0.12
# 45  2004  377.70  0.12
# 46  2005  379.98  0.12
# 47  2006  382.09  0.12
# 48  2007  384.02  0.12
# 49  2008  385.83  0.12
#     year    mean   unc
# 0   1979  336.85  0.11
# 1   1980  338.91  0.07
# 2   1981  340.11  0.09
# 3   1982  340.86  0.03
# 4   1983  342.53  0.05
# 5   1984  344.07  0.07
# 6   1985  345.54  0.07
# 7   1986  346.97  0.08
# 8   1987  348.68  0.10
# 9   1988  351.16  0.07
# 10  1989  352.79  0.07
# 11  1990  354.06  0.06
# 12  1991  355.39  0.06
# 13  1992  356.09  0.07
# 14  1993  356.83  0.07
# 15  1994  358.33  0.08
# 16  1995  360.17  0.05
# 17  1996  361.93  0.04
# 18  1997  363.05  0.04
# 19  1998  365.70  0.05
# 20  1999  367.79  0.06
# 21  2000  368.96  0.06
# 22  2001  370.57  0.04
# 23  2002  372.58  0.04
# 24  2003  375.14  0.04
# 25  2004  376.95  0.05
# 26  2005  378.98  0.05
# 27  2006  381.15  0.05
# 28  2007  382.90  0.05
# 29  2008  385.02  0.04
# 30  2009  386.50  0.04
# 31  2010  388.75  0.06
# 32  2011  390.62  0.05
# 33  2012  392.65  0.07
# 34  2013  395.40  0.06
# 35  2014  397.34  0.05
# 36  2015  399.65  0.05
# 37  2016  403.06  0.07
# 38  2017  405.22  0.08
# 39  2018  407.61  0.07
# 40  2019  410.07  0.08
# 41  2020  412.44  0.07
# 42  2021  414.70  0.07
# 43  2022  417.08  0.08
# 44  2023  419.32  0.10
#     Year  Total  Gas  Liquids  Solids  Production  Flaring  Capita
# 0   1751      3    0        0       3           0        0     NaN
# 1   1752      3    0        0       3           0        0     NaN
# 2   1753      3    0        0       3           0        0     NaN
# 3   1754      3    0        0       3           0        0     NaN
# 4   1755      3    0        0       3           0        0     NaN
# 5   1756      3    0        0       3           0        0     NaN
# 6   1757      3    0        0       3           0        0     NaN
# 7   1758      3    0        0       3           0        0     NaN
# 8   1759      3    0        0       3           0        0     NaN
# 9   1760      3    0        0       3           0        0     NaN
# 10  1761      3    0        0       3           0        0     NaN
# 11  1762      3    0        0       3           0        0     NaN
# 12  1763      3    0        0       3           0        0     NaN
# 13  1764      3    0        0       3           0        0     NaN
# 14  1765      3    0        0       3           0        0     NaN
# 15  1766      3    0        0       3           0        0     NaN
# 16  1767      3    0        0       3           0        0     NaN
# 17  1768      3    0        0       3           0        0     NaN
# 18  1769      3    0        0       3           0        0     NaN
# 19  1770      3    0        0       3           0        0     NaN
# 20  1771      4    0        0       4           0        0     NaN
# 21  1772      4    0        0       4           0        0     NaN
# 22  1773      4    0        0       4           0        0     NaN
# 23  1774      4    0        0       4           0        0     NaN
# 24  1775      4    0        0       4           0        0     NaN
# 25  1776      4    0        0       4           0        0     NaN
# 26  1777      4    0        0       4           0        0     NaN
# 27  1778      4    0        0       4           0        0     NaN
# 28  1779      4    0        0       4           0        0     NaN
# 29  1780      4    0        0       4           0        0     NaN
# <>:9: SyntaxWarning: invalid escape sequence '\s'
# <>:9: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\胡天龙\AppData\Local\Temp\ipykernel_26848\1218715712.py:9: SyntaxWarning: invalid escape sequence '\s'
#   gamma = pd.read_csv('global.1751_2014.ems', sep='\s+', skiprows=33)

# %%
# 设置年份为索引
N1_data.set_index('year', inplace=True)
N2_data.set_index('year', inplace=True)
gamma_data.set_index('Year', inplace=True)

# 获取初始条件
N1_0 = 740
N2_0 = 900

# 定义微分方程模型
def model(Y, t, k12, k21, gamma_func):
    N1, N2 = Y
    gamma_t = gamma_func(t)
    dN1dt = -k12 * N1 + k21 * N2 + gamma_t
    dN2dt = k12 * N1 - k21 * N2
    return [dN1dt, dN2dt]

# 参数
k12 = 105 / 740
k21 = 102 / 900

# 时间序列
t = np.linspace(1987, 2004, 18)

# 定义一个函数来获取gamma值
def gamma_func(t):
    idx = np.argmin(np.abs(gamma_data.index - t))
    return gamma_data.iloc[idx]['Total'] / 1000

# 求解微分方程
solution1 = odeint(model, [N1_0, N2_0], t, args=(k12, k21, gamma_func))

# 输出求解过程中的数值
for i, (time, state) in enumerate(zip(t, solution)):
    gamma_t = gamma_func(time)
    print(f"Time: {time}, N1: {state[0]}, N2: {state[1]}, gamma: {gamma_t}, k12: {k12}, k21: {k21}")

# 提取结果
N1, N2 = solution1.T
def buffer_factor(z):
    return 3.69 + 1.86e-2 * z - 1.80e-6 * z**2


def gamma_func(t):
    idx = np.argmin(np.abs(gamma_data.index - t))
    return gamma_data.iloc[idx]['Total'] / 1000
    
# 微分方程模型
def model(Y, t, k12, k21, N2_0):
    N1, N2 = Y
    xi = buffer_factor(N1)  # 计算缓冲因子
    gamma_t = gamma_func(t)  # 获取当前时间点的gamma值
    dN1dt = -k12 * N1 + k21 * (N2_00 + xi * (N2 - N2_00)) + gamma_t
    dN2dt = k12 * N1 - k21 * (N2_00 + xi * (N2 - N2_00))
    return [dN1dt, dN2dt]

# 参数
k12 = 105 / 740
k21 = 102 / 900
N2_00 = 821
# 时间序列
t = np.linspace(1987, 2004, 18)

# 求解微分方程
solution2 = odeint(model, [N1_0, N2_0], t, args=(k12, k21, N2_00))
for i, (time, state) in enumerate(zip(t, solution)):
    gamma_t = gamma_func(time)
    print(f"Time: {time}, N1: {state[0]}, N2: {state[1]}, gamma: {gamma_t}, k12: {k12}, k21: {k21}")

# 提取结果
N1_sim, N2_sim = solution2.T
plt.figure(figsize=(10, 6))
plt.plot(t, N1/2.13, label='Simulated Atmospheric CO2')
plt.plot(t, N1_sim/2.13, label='Simulated Atmospheric CO2')
plt.plot(N1_data.index, N1_data['mean'], label='Atmospheric CO2', color='blue')
plt.xlabel('Year')
plt.ylabel('Concentration (ppm)')
plt.title('CO2 Concentration Simulation')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Time: 1987.0, N1: 740.0, N2: 900.0, gamma: 5.725, k12: 0.14189189189189189, k21: 0.11333333333333333
# Time: 1988.0, N1: 805.1131787995563, N2: 840.7173215265278, gamma: 5.936, k12: 0.14189189189189189, k21: 0.11333333333333333
# Time: 1989.0, N1: 818.3989231141161, N2: 833.4325480313009, gamma: 6.066, k12: 0.14189189189189189, k21: 0.11333333333333333
# Time: 1990.0, N1: 825.0417861611991, N2: 832.8596334012207, gamma: 6.074, k12: 0.14189189189189189, k21: 0.11333333333333333
# Time: 1991.0, N1: 830.9144033359579, N2: 833.0950221647521, gamma: 6.142, k12: 0.14189189189189189, k21: 0.11333333333333333
# Time: 1992.0, N1: 836.6941377256109, N2: 833.4252880174424, gamma: 6.078, k12: 0.14189189189189189, k21: 0.11333333333333333
# Time: 1993.0, N1: 842.4317207898022, N2: 833.7616981556683, gamma: 6.07, k12: 0.14189189189189189, k21: 0.11333333333333333
# Time: 1994.0, N1: 848.218650803147, N2: 834.0967723832681, gamma: 6.174, k12: 0.14189189189189189, k21: 0.11333333333333333
# Time: 1995.0, N1: 854.1209171632095, N2: 834.4340124605046, gamma: 6.305, k12: 0.14189189189189189, k21: 0.11333333333333333
# Time: 1996.0, N1: 860.1563599644139, N2: 834.7750727143272, gamma: 6.448, k12: 0.14189189189189189, k21: 0.11333333333333333
# Time: 1997.0, N1: 866.3133206391288, N2: 835.1201172488973, gamma: 6.556, k12: 0.14189189189189189, k21: 0.11333333333333333
# Time: 1998.0, N1: 872.5324789373767, N2: 835.4669531597184, gamma: 6.576, k12: 0.14189189189189189, k21: 0.11333333333333333
# Time: 1999.0, N1: 878.7561051937622, N2: 835.8118241217883, gamma: 6.561, k12: 0.14189189189189189, k21: 0.11333333333333333
# Time: 2000.0, N1: 885.0600441659833, N2: 836.1548846562566, gamma: 6.733, k12: 0.14189189189189189, k21: 0.11333333333333333
# Time: 2001.0, N1: 891.5257474614592, N2: 836.5021812242558, gamma: 6.893, k12: 0.14189189189189189, k21: 0.11333333333333333
# Time: 2002.0, N1: 898.1177847766446, N2: 836.853644897043, gamma: 6.994, k12: 0.14189189189189189, k21: 0.11333333333333333
# Time: 2003.0, N1: 904.9464427609904, N2: 837.2099939871272, gamma: 7.376, k12: 0.14189189189189189, k21: 0.11333333333333333
# Time: 2004.0, N1: 912.1359370654031, N2: 837.579973741196, gamma: 7.743, k12: 0.14189189189189189, k21: 0.11333333333333333
# Time: 1987.0, N1: 740.0, N2: 900.0, gamma: 5.725, k12: 0.14189189189189189, k21: 0.11333333333333333
# Time: 1988.0, N1: 805.1131787995563, N2: 840.7173215265278, gamma: 5.936, k12: 0.14189189189189189, k21: 0.11333333333333333
# Time: 1989.0, N1: 818.3989231141161, N2: 833.4325480313009, gamma: 6.066, k12: 0.14189189189189189, k21: 0.11333333333333333
# Time: 1990.0, N1: 825.0417861611991, N2: 832.8596334012207, gamma: 6.074, k12: 0.14189189189189189, k21: 0.11333333333333333
# Time: 1991.0, N1: 830.9144033359579, N2: 833.0950221647521, gamma: 6.142, k12: 0.14189189189189189, k21: 0.11333333333333333
# Time: 1992.0, N1: 836.6941377256109, N2: 833.4252880174424, gamma: 6.078, k12: 0.14189189189189189, k21: 0.11333333333333333
# Time: 1993.0, N1: 842.4317207898022, N2: 833.7616981556683, gamma: 6.07, k12: 0.14189189189189189, k21: 0.11333333333333333
# Time: 1994.0, N1: 848.218650803147, N2: 834.0967723832681, gamma: 6.174, k12: 0.14189189189189189, k21: 0.11333333333333333
# Time: 1995.0, N1: 854.1209171632095, N2: 834.4340124605046, gamma: 6.305, k12: 0.14189189189189189, k21: 0.11333333333333333
# Time: 1996.0, N1: 860.1563599644139, N2: 834.7750727143272, gamma: 6.448, k12: 0.14189189189189189, k21: 0.11333333333333333
# Time: 1997.0, N1: 866.3133206391288, N2: 835.1201172488973, gamma: 6.556, k12: 0.14189189189189189, k21: 0.11333333333333333
# Time: 1998.0, N1: 872.5324789373767, N2: 835.4669531597184, gamma: 6.576, k12: 0.14189189189189189, k21: 0.11333333333333333
# Time: 1999.0, N1: 878.7561051937622, N2: 835.8118241217883, gamma: 6.561, k12: 0.14189189189189189, k21: 0.11333333333333333
# Time: 2000.0, N1: 885.0600441659833, N2: 836.1548846562566, gamma: 6.733, k12: 0.14189189189189189, k21: 0.11333333333333333
# Time: 2001.0, N1: 891.5257474614592, N2: 836.5021812242558, gamma: 6.893, k12: 0.14189189189189189, k21: 0.11333333333333333
# Time: 2002.0, N1: 898.1177847766446, N2: 836.853644897043, gamma: 6.994, k12: 0.14189189189189189, k21: 0.11333333333333333
# Time: 2003.0, N1: 904.9464427609904, N2: 837.2099939871272, gamma: 7.376, k12: 0.14189189189189189, k21: 0.11333333333333333
# Time: 2004.0, N1: 912.1359370654031, N2: 837.579973741196, gamma: 7.743, k12: 0.14189189189189189, k21: 0.11333333333333333
